# %% [markdown]
# # Toxicity Detector — Analysis Notebook
#
# This notebook evaluates the toxicity detector using:
# - Sample safe evaluation dataset
# - Score distribution
# - Threshold analysis
#
# **Note:** This notebook uses *non-harmful* example text only.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt

safe_samples = [
    'I need help with my project.',
    'Hello, how are you?',
    'Can you explain this concept?',
    'This is confusing, can you clarify?'
]

# %%
def mock_toxicity_detector(text):
    # Always safe for this notebook
    return 0.0

scores = [mock_toxicity_detector(t) for t in safe_samples]
scores

# %%
plt.figure(figsize=(6,4))
plt.hist(scores, bins=5, color='green')
plt.title('Toxicity Score Distribution (Safe Samples)')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()
